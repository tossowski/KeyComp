# %%
import random
from matplotlib import pyplot as plt
random.seed(0)

def get_performances(filename):
    categories = {
        "Non_Compositional": [72, 73, 74, 95, 96, 133, 149, 150, 164, 218, 221, 222, 224, 235, 237, 246, 274, 275, 321, 325, 326, 327, 332, 333, 334, 350, 364, 365, 398, 399],
        "Ambiguously_Correct": [3, 13, 36, 46, 75, 76, 77, 78, 82, 86, 88, 113, 119, 121, 131, 132, 133, 148, 189, 220, 221, 262, 263, 287, 295, 300, 303, 305, 307, 310, 319, 322, 332, 340, 343, 344, 348, 353, 355, 356, 363, 374, 377, 381, 386, 394],
        "Visually_Difficult": [4, 22, 23, 25, 27, 28, 31, 36, 58, 65, 69, 70, 77, 97, 116, 118, 134, 138, 159, 163, 172, 176, 182, 187, 200, 214, 226, 227, 232, 241, 255, 268, 286, 335, 352, 356, 373, 376],
        "Unusual_Image" : [31, 36, 38, 41, 42, 61, 62, 70, 78, 84, 93, 110, 114, 116, 128, 133, 136, 155, 159, 164, 173, 174, 188, 201, 203, 204, 206, 209, 218, 223, 239, 245, 246, 247, 254, 274, 275, 277, 280, 282, 293, 303, 307, 314, 319, 320, 327, 329, 339, 362, 367, 383, 384, 388, 393, 395],
        "Unusual_Text": [10, 41, 49, 58, 63, 68, 70, 152, 156, 159, 163, 174, 198, 201, 209, 214, 215, 221, 229, 233, 237, 253, 257, 264, 275, 287, 303, 315, 318, 323, 324, 326, 327, 335, 338, 342, 343, 345, 346, 351, 354, 359, 364, 376, 383, 385, 386, 387, 390, 394],
        "Complex_Reasoning": [16, 40, 44, 46, 55, 58, 81, 83, 93, 97, 103, 111, 116, 118, 128, 130, 135, 143, 144, 176, 190, 191, 192, 193, 199, 206, 208, 209, 210, 211, 217, 218, 219, 227, 228, 230, 234, 238, 241, 242, 249, 254, 258, 260, 262, 264, 267, 268, 275, 276, 281, 284, 286, 287, 292, 295, 296, 298, 299, 304, 311, 312, 316, 330, 331, 334, 336, 342, 347, 358, 361, 371, 373, 375, 382, 383, 392, 396],
        "NoTag": [0, 1, 2, 5, 6, 7, 8, 9, 11, 12, 14, 15, 17, 18, 19, 20, 21, 24, 26, 29, 30, 32, 33, 34, 35, 37, 39, 43, 45, 47, 48, 50, 51, 52, 53, 54, 56, 57, 59, 60, 64, 66, 67, 71, 79, 80, 85, 87, 89, 90, 91, 92, 94, 98, 99, 100, 101, 102, 104, 105, 106, 107, 108, 109, 112, 115, 117, 120, 122, 123, 124, 125, 126, 127, 129, 137, 139, 140, 141, 142, 145, 146, 147, 151, 153, 154, 157, 158, 160, 161, 162, 165, 166, 167, 168, 169, 170, 171, 175, 177, 178, 179, 180, 181, 183, 184, 185, 186, 194, 195, 196, 197, 202, 205, 207, 212, 213, 216, 225, 231, 236, 240, 243, 244, 248, 250, 251, 252, 256, 259, 261, 265, 266, 269, 270, 271, 272, 273, 278, 279, 283, 285, 288, 289, 290, 291, 294, 297, 301, 302, 306, 308, 309, 317, 328, 337, 341, 349, 357, 360, 366, 368, 369, 370, 372, 378, 379, 380, 389, 391, 397, 313]
    }

    id_to_category = {}
    for category in categories:
        for num in categories[category]:
            id_to_category[num] = category


    performances = {}
    totals = {}
    corrects = {}
    for category in categories:
        performances[category] = 0
        totals[category] = 0
        corrects[category] = 0

    for d in range(2):   
        with open(filename.format(d+1), "r") as f:
            stats = {}

            for line in f:

                info, response = line.split("|||")
                example_num, label = info.split("_")
                example_num = int(example_num)
                label = int(label)
                if example_num not in stats:
                    stats[example_num] = [False, False]
                if label == 0:
                    if response[0] == "A":
                        stats[example_num][0] = True
                    elif response[0] == "B":
                        stats[example_num][0] = False
                    else:
                        stats[example_num][0] = True if random.random() > 0.5 else False
                if label == 1:
                    if response[0] == "B":
                        stats[example_num][1] = True
                    elif response[0] == "A":
                        stats[example_num][1] = False
                    else:
                        stats[example_num][1] = True if random.random() > 0.5 else False
        correct = 0
        total = 0
        for example in stats:
            predictions = stats[example]
            category = id_to_category[example]
            totals[category] += 1
            if predictions[0] and predictions[1]:
                correct += 1
                corrects[category] += 1
            total += 1

        # for category in totals:
        #     print(category, totals[category])

        for category in totals:
            performances[category] = corrects[category] / totals[category] * 100
        print(correct / total)

        for performance in performances:
            print(f"{performance}, {performances[performance]}")

    return performances, totals

text_performance_best, totals = get_performances("final_preds/best_description_text_{}.txt")
text_performance_no_cot, totals = get_performances("final_preds/predictions_keywords_no_cot_{}.txt")
text_performance_no_keywords, totals = get_performances("final_preds/predictions_no_keywords_text_{}.txt")

QUESTION_COMPOSITION = totals
order = sorted(text_performance_best, key = lambda x: totals.get(x))
TEXT_UPPER_BOUND = [text_performance_best[x] for x in order]
TEXT_NO_COT = [text_performance_no_cot[x] for x in order]
TEXT_NO_KEYWORDS = [text_performance_no_keywords[x] for x in order]


plt.figure(figsize=(18,7))
width = 0.15
s = 0.08
plt.title("Text Scores for Different Methods on Winoground")
plt.xlabel("Question Type")
plt.ylabel("Accuracy")

plt.bar([int(x) - s * 3 for x in range(len(order))], TEXT_UPPER_BOUND, width=width, label="Caption Selection", color="#cd5a3f")

plt.bar([int(x) + s for x in range(len(order))], TEXT_NO_COT, width=width, label="No Chain of Thought", color="#78ca99")
plt.bar([int(x) + s * 3 for x in range(len(order))], TEXT_NO_KEYWORDS, width=width, label="No Keyword Extraction", color="#E5BA73")
#plt.axhline(y = 42.50, color = 'black', linestyle = '--', label="IAIS (State of the Art)")

plt.tight_layout()
plt.legend(loc='upper right', prop={"size":14}, ncol=5, frameon=False)
plt.xticks(range(len(order)), labels=[f"{x}\n{QUESTION_COMPOSITION[x] / sum(QUESTION_COMPOSITION.values()) * 100:.1f}%" for x in order])
# Out:
# 0.39
# Non_Compositional, 52.94117647058824
# Ambiguously_Correct, 36.666666666666664
# Visually_Difficult, 45.0
# Unusual_Image, 37.5
# Unusual_Text, 34.883720930232556
# Complex_Reasoning, 34.61538461538461
# NoTag, 40.69767441860465
# 0.41
# Non_Compositional, 52.94117647058824
# Ambiguously_Correct, 33.33333333333333
# Visually_Difficult, 45.0
# Unusual_Image, 43.75
# Unusual_Text, 33.72093023255814
# Complex_Reasoning, 37.17948717948718
# NoTag, 41.27906976744186
# 0.31
# Non_Compositional, 52.94117647058824
# Ambiguously_Correct, 23.333333333333332
# Visually_Difficult, 55.00000000000001
# Unusual_Image, 17.5
# Unusual_Text, 23.25581395348837
# Complex_Reasoning, 32.05128205128205
# NoTag, 31.976744186046513
# 0.3125
# Non_Compositional, 50.0
# Ambiguously_Correct, 30.0
# Visually_Difficult, 52.5
# Unusual_Image, 17.5
# Unusual_Text, 22.093023255813954
# Complex_Reasoning, 32.05128205128205
# NoTag, 31.976744186046513
# 0.3
# Non_Compositional, 47.05882352941176
# Ambiguously_Correct, 33.33333333333333
# Visually_Difficult, 35.0
# Unusual_Image, 17.5
# Unusual_Text, 32.55813953488372
# Complex_Reasoning, 24.358974358974358
# NoTag, 31.976744186046513
# 0.3175
# Non_Compositional, 52.94117647058824
# Ambiguously_Correct, 28.333333333333332
# Visually_Difficult, 32.5
# Unusual_Image, 23.75
# Unusual_Text, 34.883720930232556
# Complex_Reasoning, 25.64102564102564
# NoTag, 31.976744186046513
# ([<matplotlib.axis.XTick at 0x7ff3177b5400>,
#   <matplotlib.axis.XTick at 0x7ff3177b53d0>,
#   <matplotlib.axis.XTick at 0x7ff3178948e0>,
#   <matplotlib.axis.XTick at 0x7ff317696d60>,
#   <matplotlib.axis.XTick at 0x7ff3176a3bb0>,
#   <matplotlib.axis.XTick at 0x7ff3176aa6a0>,
#   <matplotlib.axis.XTick at 0x7ff3176aadf0>],
#  [Text(0, 0, 'Non_Compositional\n4.2%'),
#   Text(1, 0, 'Visually_Difficult\n5.0%'),
#   Text(2, 0, 'Ambiguously_Correct\n7.5%'),
#   Text(3, 0, 'Unusual_Image\n10.0%'),
#   Text(4, 0, 'Unusual_Text\n10.8%'),
#   Text(5, 0, 'Complex_Reasoning\n19.5%'),
#   Text(6, 0, 'NoTag\n43.0%')])

# %%
from matplotlib import pyplot as plt
from datasets import load_dataset
from textwrap import wrap
auth_token = "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"  # Replace with an auth token, which you can get from your huggingface account: Profile -> Settings -> Access Tokens -> New Token
# winoground = load_dataset("facebook/winoground", use_auth_token=auth_token)["test"]

categories = {
    "Non_Compositional": [72, 73, 74, 95, 96, 133, 149, 150, 164, 218, 221, 222, 224, 235, 237, 246, 274, 275, 321, 325, 326, 327, 332, 333, 334, 350, 364, 365, 398, 399],
    "Ambiguously_Correct": [3, 13, 36, 46, 75, 76, 77, 78, 82, 86, 88, 113, 119, 121, 131, 132, 133, 148, 189, 220, 221, 262, 263, 287, 295, 300, 303, 305, 307, 310, 319, 322, 332, 340, 343, 344, 348, 353, 355, 356, 363, 374, 377, 381, 386, 394],
    "Visually_Difficult": [4, 22, 23, 25, 27, 28, 31, 36, 58, 65, 69, 70, 77, 97, 116, 118, 134, 138, 159, 163, 172, 176, 182, 187, 200, 214, 226, 227, 232, 241, 255, 268, 286, 335, 352, 356, 373, 376],
    "Unusual_Image" : [31, 36, 38, 41, 42, 61, 62, 70, 78, 84, 93, 110, 114, 116, 128, 133, 136, 155, 159, 164, 173, 174, 188, 201, 203, 204, 206, 209, 218, 223, 239, 245, 246, 247, 254, 274, 275, 277, 280, 282, 293, 303, 307, 314, 319, 320, 327, 329, 339, 362, 367, 383, 384, 388, 393, 395],
    "Unusual_Text": [10, 41, 49, 58, 63, 68, 70, 152, 156, 159, 163, 174, 198, 201, 209, 214, 215, 221, 229, 233, 237, 253, 257, 264, 275, 287, 303, 315, 318, 323, 324, 326, 327, 335, 338, 342, 343, 345, 346, 351, 354, 359, 364, 376, 383, 385, 386, 387, 390, 394],
    "Complex_Reasoning": [16, 40, 44, 46, 55, 58, 81, 83, 93, 97, 103, 111, 116, 118, 128, 130, 135, 143, 144, 176, 190, 191, 192, 193, 199, 206, 208, 209, 210, 211, 217, 218, 219, 227, 228, 230, 234, 238, 241, 242, 249, 254, 258, 260, 262, 264, 267, 268, 275, 276, 281, 284, 286, 287, 292, 295, 296, 298, 299, 304, 311, 312, 316, 330, 331, 334, 336, 342, 347, 358, 361, 371, 373, 375, 382, 383, 392, 396],
    "NoTag": [0, 1, 2, 5, 6, 7, 8, 9, 11, 12, 14, 15, 17, 18, 19, 20, 21, 24, 26, 29, 30, 32, 33, 34, 35, 37, 39, 43, 45, 47, 48, 50, 51, 52, 53, 54, 56, 57, 59, 60, 64, 66, 67, 71, 79, 80, 85, 87, 89, 90, 91, 92, 94, 98, 99, 100, 101, 102, 104, 105, 106, 107, 108, 109, 112, 115, 117, 120, 122, 123, 124, 125, 126, 127, 129, 137, 139, 140, 141, 142, 145, 146, 147, 151, 153, 154, 157, 158, 160, 161, 162, 165, 166, 167, 168, 169, 170, 171, 175, 177, 178, 179, 180, 181, 183, 184, 185, 186, 194, 195, 196, 197, 202, 205, 207, 212, 213, 216, 225, 231, 236, 240, 243, 244, 248, 250, 251, 252, 256, 259, 261, 265, 266, 269, 270, 271, 272, 273, 278, 279, 283, 285, 288, 289, 290, 291, 294, 297, 301, 302, 306, 308, 309, 317, 328, 337, 341, 349, 357, 360, 366, 368, 369, 370, 372, 378, 379, 380, 389, 391, 397, 313]
}

id_to_category = {}
for category in categories:
    for num in categories[category]:
        id_to_category[num] = category


performances = {}
totals = {}
corrects = {}
for category in categories:
    performances[category] = 0
    totals[category] = 0
    corrects[category] = 0

with open("chatgpt_outputs/best_description_image_score_no_cot_3.txt", "r") as f:
    total = 0
    correct = 0
    for line in f:
        example_num, response1, response2 = line.split("|||")
        example_num = int(example_num)
        # image_0 = winoground[example_num]["image_0"]
        # image_1 = winoground[example_num]["image_1"]
        #fig, ax = plt.subplots(1,2,figsize=(20,10))
        # ax[0].imshow(image_0)
        # ax[0].set_xlabel("\n".join(wrap(response1, 60)))
        # ax[1].imshow(image_1)
        # ax[1].set_xlabel("\n".join(wrap(response2, 60)))
        # plt.savefig(f"test/{total}.png")
        category = id_to_category[example_num]
        totals[category] += 1
        if response1[0] == "A" and response2[0] == "B":
            correct += 1
            corrects[category] += 1
        total += 1
        #plt.close()

# for category in totals:
#     print(category, totals[category])

for category in totals:
    performances[category] = round(corrects[category] / totals[category] * 100, 2)
print(correct / total)
print(total)
print(performances)
print(corrects["Complex_Reasoning"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 35
#      33 correct = 0
#      34 for line in f:
# ---> 35     example_num, response1, response2 = line.split("|||")
#      36     example_num = int(example_num)
#      37     # image_0 = winoground[example_num]["image_0"]
#      38     # image_1 = winoground[example_num]["image_1"]
#      39     #fig, ax = plt.subplots(1,2,figsize=(20,10))
#    (...)
#      43     # ax[1].set_xlabel("\n".join(wrap(response2, 60)))
#      44     # plt.savefig(f"test/{total}.png")
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
# New Image Score Prompt
auth_token = "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"  # Replace with an auth token, which you can get from your huggingface account: Profile -> Settings -> Access Tokens -> New Token
#winoground = load_dataset("facebook/winoground", use_auth_token=auth_token)["test"]

categories = {
    "Non_Compositional": [72, 73, 74, 95, 96, 133, 149, 150, 164, 218, 221, 222, 224, 235, 237, 246, 274, 275, 321, 325, 326, 327, 332, 333, 334, 350, 364, 365, 398, 399],
    "Ambiguously_Correct": [3, 13, 36, 46, 75, 76, 77, 78, 82, 86, 88, 113, 119, 121, 131, 132, 133, 148, 189, 220, 221, 262, 263, 287, 295, 300, 303, 305, 307, 310, 319, 322, 332, 340, 343, 344, 348, 353, 355, 356, 363, 374, 377, 381, 386, 394],
    "Visually_Difficult": [4, 22, 23, 25, 27, 28, 31, 36, 58, 65, 69, 70, 77, 97, 116, 118, 134, 138, 159, 163, 172, 176, 182, 187, 200, 214, 226, 227, 232, 241, 255, 268, 286, 335, 352, 356, 373, 376],
    "Unusual_Image" : [31, 36, 38, 41, 42, 61, 62, 70, 78, 84, 93, 110, 114, 116, 128, 133, 136, 155, 159, 164, 173, 174, 188, 201, 203, 204, 206, 209, 218, 223, 239, 245, 246, 247, 254, 274, 275, 277, 280, 282, 293, 303, 307, 314, 319, 320, 327, 329, 339, 362, 367, 383, 384, 388, 393, 395],
    "Unusual_Text": [10, 41, 49, 58, 63, 68, 70, 152, 156, 159, 163, 174, 198, 201, 209, 214, 215, 221, 229, 233, 237, 253, 257, 264, 275, 287, 303, 315, 318, 323, 324, 326, 327, 335, 338, 342, 343, 345, 346, 351, 354, 359, 364, 376, 383, 385, 386, 387, 390, 394],
    "Complex_Reasoning": [16, 40, 44, 46, 55, 58, 81, 83, 93, 97, 103, 111, 116, 118, 128, 130, 135, 143, 144, 176, 190, 191, 192, 193, 199, 206, 208, 209, 210, 211, 217, 218, 219, 227, 228, 230, 234, 238, 241, 242, 249, 254, 258, 260, 262, 264, 267, 268, 275, 276, 281, 284, 286, 287, 292, 295, 296, 298, 299, 304, 311, 312, 316, 330, 331, 334, 336, 342, 347, 358, 361, 371, 373, 375, 382, 383, 392, 396],
    "NoTag": [0, 1, 2, 5, 6, 7, 8, 9, 11, 12, 14, 15, 17, 18, 19, 20, 21, 24, 26, 29, 30, 32, 33, 34, 35, 37, 39, 43, 45, 47, 48, 50, 51, 52, 53, 54, 56, 57, 59, 60, 64, 66, 67, 71, 79, 80, 85, 87, 89, 90, 91, 92, 94, 98, 99, 100, 101, 102, 104, 105, 106, 107, 108, 109, 112, 115, 117, 120, 122, 123, 124, 125, 126, 127, 129, 137, 139, 140, 141, 142, 145, 146, 147, 151, 153, 154, 157, 158, 160, 161, 162, 165, 166, 167, 168, 169, 170, 171, 175, 177, 178, 179, 180, 181, 183, 184, 185, 186, 194, 195, 196, 197, 202, 205, 207, 212, 213, 216, 225, 231, 236, 240, 243, 244, 248, 250, 251, 252, 256, 259, 261, 265, 266, 269, 270, 271, 272, 273, 278, 279, 283, 285, 288, 289, 290, 291, 294, 297, 301, 302, 306, 308, 309, 317, 328, 337, 341, 349, 357, 360, 366, 368, 369, 370, 372, 378, 379, 380, 389, 391, 397, 313]
}

id_to_category = {}
for category in categories:
    for num in categories[category]:
        id_to_category[num] = category


performances = {}
totals = {}
corrects = {}
for category in categories:
    performances[category] = 0
    totals[category] = 0
    corrects[category] = 0

with open("final_test/simple_select_0.txt", "r") as f:
    total = 0
    correct = 0
    for line in f:
        example_num, response1, response2 = line.split("|||")
        example_num = int(example_num)
        #image_0 = winoground[example_num]["image_0"]
        #image_1 = winoground[example_num]["image_1"]
        #fig, ax = plt.subplots(1,2,figsize=(20,10))
        # ax[0].imshow(image_0)
        # ax[0].set_xlabel("\n".join(wrap(response1, 60)))
        # ax[1].imshow(image_1)
        # ax[1].set_xlabel("\n".join(wrap(response2, 60)))
        # plt.savefig(f"test/{total}.png")
        category = id_to_category[example_num]
        totals[category] += 1

        if response1[0] == "A" and response2[0] == "B":
            correct += 1
            corrects[category] += 1
        total += 1
        #plt.close()

# for category in totals:
#     print(category, totals[category])

# for category in totals:
#     performances[category] = round(corrects[category] / totals[category] * 100,2)
print(correct / total)
print(total)
print(performances)
print(corrects["Complex_Reasoning"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[141], line 33
#      31 correct = 0
#      32 for line in f:
# ---> 33     example_num, response1, response2 = line.split("|||")
#      34     example_num = int(example_num)
#      35     #image_0 = winoground[example_num]["image_0"]
#      36     #image_1 = winoground[example_num]["image_1"]
#      37     #fig, ax = plt.subplots(1,2,figsize=(20,10))
#    (...)
#      41     # ax[1].set_xlabel("\n".join(wrap(response2, 60)))
#      42     # plt.savefig(f"test/{total}.png")
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
# Group score
from matplotlib import pyplot as plt
from datasets import load_dataset
from textwrap import wrap
import random
import numpy as np
random.seed(42)
text_scores = []
image_scores = []
image_performances = []
text_performances = []
group_scores = []
for i in range(3):
    image_path = f"final_test/cot_image_{i+1}.txt"
    text_path = f"final_test/cot_text_{i+1}.txt"
    auth_token = "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"  # Replace with an auth token, which you can get from your huggingface account: Profile -> Settings -> Access Tokens -> New Token
    print(image_path)

    categories = {
        "Non_Compositional": [72, 73, 74, 95, 96, 133, 149, 150, 164, 218, 221, 222, 224, 235, 237, 246, 274, 275, 321, 325, 326, 327, 332, 333, 334, 350, 364, 365, 398, 399],
        "Ambiguously_Correct": [3, 13, 36, 46, 75, 76, 77, 78, 82, 86, 88, 113, 119, 121, 131, 132, 133, 148, 189, 220, 221, 262, 263, 287, 295, 300, 303, 305, 307, 310, 319, 322, 332, 340, 343, 344, 348, 353, 355, 356, 363, 374, 377, 381, 386, 394],
        "Visually_Difficult": [4, 22, 23, 25, 27, 28, 31, 36, 58, 65, 69, 70, 77, 97, 116, 118, 134, 138, 159, 163, 172, 176, 182, 187, 200, 214, 226, 227, 232, 241, 255, 268, 286, 335, 352, 356, 373, 376],
        "Unusual_Image" : [31, 36, 38, 41, 42, 61, 62, 70, 78, 84, 93, 110, 114, 116, 128, 133, 136, 155, 159, 164, 173, 174, 188, 201, 203, 204, 206, 209, 218, 223, 239, 245, 246, 247, 254, 274, 275, 277, 280, 282, 293, 303, 307, 314, 319, 320, 327, 329, 339, 362, 367, 383, 384, 388, 393, 395],
        "Unusual_Text": [10, 41, 49, 58, 63, 68, 70, 152, 156, 159, 163, 174, 198, 201, 209, 214, 215, 221, 229, 233, 237, 253, 257, 264, 275, 287, 303, 315, 318, 323, 324, 326, 327, 335, 338, 342, 343, 345, 346, 351, 354, 359, 364, 376, 383, 385, 386, 387, 390, 394],
        "Complex_Reasoning": [16, 40, 44, 46, 55, 58, 81, 83, 93, 97, 103, 111, 116, 118, 128, 130, 135, 143, 144, 176, 190, 191, 192, 193, 199, 206, 208, 209, 210, 211, 217, 218, 219, 227, 228, 230, 234, 238, 241, 242, 249, 254, 258, 260, 262, 264, 267, 268, 275, 276, 281, 284, 286, 287, 292, 295, 296, 298, 299, 304, 311, 312, 316, 330, 331, 334, 336, 342, 347, 358, 361, 371, 373, 375, 382, 383, 392, 396],
        "NoTag": [0, 1, 2, 5, 6, 7, 8, 9, 11, 12, 14, 15, 17, 18, 19, 20, 21, 24, 26, 29, 30, 32, 33, 34, 35, 37, 39, 43, 45, 47, 48, 50, 51, 52, 53, 54, 56, 57, 59, 60, 64, 66, 67, 71, 79, 80, 85, 87, 89, 90, 91, 92, 94, 98, 99, 100, 101, 102, 104, 105, 106, 107, 108, 109, 112, 115, 117, 120, 122, 123, 124, 125, 126, 127, 129, 137, 139, 140, 141, 142, 145, 146, 147, 151, 153, 154, 157, 158, 160, 161, 162, 165, 166, 167, 168, 169, 170, 171, 175, 177, 178, 179, 180, 181, 183, 184, 185, 186, 194, 195, 196, 197, 202, 205, 207, 212, 213, 216, 225, 231, 236, 240, 243, 244, 248, 250, 251, 252, 256, 259, 261, 265, 266, 269, 270, 271, 272, 273, 278, 279, 283, 285, 288, 289, 290, 291, 294, 297, 301, 302, 306, 308, 309, 317, 328, 337, 341, 349, 357, 360, 366, 368, 369, 370, 372, 378, 379, 380, 389, 391, 397, 313]
    }

    id_to_category = {}
    for category in categories:
        for num in categories[category]:
            id_to_category[num] = category

    invalid = 0
    performances = {}
    totals = {}
    corrects = {}
    for category in categories:
        performances[category] = 0
        totals[category] = 0
        corrects[category] = 0

    with open(text_path, "r") as f:
        stats = {}

        for line in f:

            info, response = line.split("|||")
            example_num, label = info.split("_")
            example_num = int(example_num)
            label = int(label)
            if example_num not in stats:
                stats[example_num] = [False, False]
            if label == 0:
                if response[0] == "A":
                    stats[example_num][0] = True
                elif response[0] == "B":
                    stats[example_num][0] = False
                else:
                    invalid += 1
                    # stats[example_num][0] = True if random.random() > 0.5 else False
            if label == 1:
                if response[0] == "B":
                    stats[example_num][1] = True
                elif response[0] == "A":
                    stats[example_num][1] = False
                else:
                    invalid += 1
                    # stats[example_num][1] = True if random.random() > 0.5 else False
    correct = 0
    total = 0

    for example in stats:
        predictions = stats[example]
        category = id_to_category[example]
        totals[category] += 1
        if predictions[0] and predictions[1]:
            correct += 1
            corrects[category] += 1
        total += 1

    for category in totals:
        performances[category] = round(corrects[category] / totals[category] * 100,2)

    text_score = correct / total
    #print("hi")
    #print(performances)
    text_performances.append(performances)
    #print(text_score)
    id_to_category = {}
    for category in categories:
        for num in categories[category]:
            id_to_category[num] = category


    performances = {}
    totals = {}
    corrects = {}
    for category in categories:
        performances[category] = 0
        totals[category] = 0
        corrects[category] = 0

    group_correct = 0
    with open(image_path, "r") as f:
        total = 0
        correct = 0
        for line in f:
            example_num, response1, response2 = line.split("|||")
            example_num = int(example_num)
            #fig, ax = plt.subplots(1,2,figsize=(20,10))
            # ax[0].imshow(image_0)
            # ax[0].set_xlabel("\n".join(wrap(response1, 60)))
            # ax[1].imshow(image_1)
            # ax[1].set_xlabel("\n".join(wrap(response2, 60)))
            # plt.savefig(f"test/{total}.png")
            category = id_to_category[example_num]
            totals[category] += 1
            first_image_correct = False
            second_image_correct = False

            if response1[10] == "A":
                first_image_correct = True
            elif response1[10] == "B":
                first_image_correct = False
            # else:
            #     first_image_correct = True if random.random() > 0.5 else False

            if response2[10] == "B":
                second_image_correct = True
            elif response2[10] == "A":
                second_image_correct = False
            # else:
            #     second_image_correct = True if random.random() > 0.5 else False


            if first_image_correct and second_image_correct:
                correct += 1
                if stats[example_num][0] and stats[example_num][1]:
                    group_correct += 1
                corrects[category] += 1
            total += 1
            #plt.close()

    # for category in totals:
    #     print(category, totals[category])

    for category in totals:
        performances[category] = round(corrects[category] / totals[category] * 100,2)
    #print(performances)
    image_score = correct/total
    group_score = group_correct / total
    #print(text_score, image_score, group_score)
    text_scores.append(text_score)
    image_scores.append(image_score)
    image_performances.append(performances)
    group_scores.append(group_score)
print(image_scores, text_scores, group_scores, image_performances, text_performances)
print(f"Average Text Score: {sum(text_scores) / len(text_scores):.4f}")
print(f"Average Image Score: {sum(image_scores) / len(image_scores):.4f}")
print(f"Average Group Score: {sum(group_scores) / len(group_scores):.4f}")

print(f"STD Text Score: {np.std(np.array(text_scores), ddof=1) * 100:.4f}")
print(f"STD Image Score: {np.std(image_scores,  ddof=1) * 100:.4f}")
print(f"STD Group Score: {np.std(group_scores, ddof=1) * 100:.4f}")

avg_image = {}
for performance in image_performances:
    for category in performance:
        if category not in avg_image:
            avg_image[category] = 0
        avg_image[category] += performance[category]
for category in avg_image:
    avg_image[category] /= len(image_scores)

avg_text = {}
for performance in text_performances:
    for category in performance:
        if category not in avg_text:
            avg_text[category] = 0
        avg_text[category] += performance[category]
for category in avg_text:
    avg_text[category] /= len(image_scores)


avg_text
# Out:
# final_test/cot_image_1.txt
# final_test/cot_image_2.txt
# final_test/cot_image_3.txt
# [0.2575, 0.245, 0.23651452282157676] [0.29, 0.2975, 0.32] [0.1125, 0.1225, 0.13692946058091288] [{'Non_Compositional': 52.94, 'Ambiguously_Correct': 10.0, 'Visually_Difficult': 30.0, 'Unusual_Image': 25.0, 'Unusual_Text': 20.93, 'Complex_Reasoning': 20.51, 'NoTag': 29.07}, {'Non_Compositional': 52.94, 'Ambiguously_Correct': 16.67, 'Visually_Difficult': 35.0, 'Unusual_Image': 25.0, 'Unusual_Text': 18.6, 'Complex_Reasoning': 16.67, 'NoTag': 26.74}, {'Non_Compositional': 60.0, 'Ambiguously_Correct': 26.67, 'Visually_Difficult': 41.18, 'Unusual_Image': 15.0, 'Unusual_Text': 10.53, 'Complex_Reasoning': 13.16, 'NoTag': 24.59}] [{'Non_Compositional': 64.71, 'Ambiguously_Correct': 33.33, 'Visually_Difficult': 30.0, 'Unusual_Image': 25.0, 'Unusual_Text': 16.28, 'Complex_Reasoning': 19.23, 'NoTag': 33.14}, {'Non_Compositional': 47.06, 'Ambiguously_Correct': 36.67, 'Visually_Difficult': 40.0, 'Unusual_Image': 20.0, 'Unusual_Text': 20.93, 'Complex_Reasoning': 24.36, 'NoTag': 32.56}, {'Non_Compositional': 52.94, 'Ambiguously_Correct': 30.0, 'Visually_Difficult': 50.0, 'Unusual_Image': 20.0, 'Unusual_Text': 20.93, 'Complex_Reasoning': 29.49, 'NoTag': 34.88}]
# Average Text Score: 0.3025
# Average Image Score: 0.2463
# Average Group Score: 0.1240
# STD Text Score: 1.5612
# STD Image Score: 1.0557
# STD Group Score: 1.2281
# {'Non_Compositional': 54.90333333333333,
#  'Ambiguously_Correct': 33.333333333333336,
#  'Visually_Difficult': 40.0,
#  'Unusual_Image': 21.666666666666668,
#  'Unusual_Text': 19.38,
#  'Complex_Reasoning': 24.36,
#  'NoTag': 33.52666666666667}

# %%
# Group score
from matplotlib import pyplot as plt
from datasets import load_dataset
from textwrap import wrap
import random
random.seed(42)
print("hi")
text_path = "final_preds/best_description_text_{}.txt"

auth_token = "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"  # Replace with an auth token, which you can get from your huggingface account: Profile -> Settings -> Access Tokens -> New Token
winoground = load_dataset("facebook/winoground", use_auth_token=auth_token)["test"]

categories = {
    "Non_Compositional": [72, 73, 74, 95, 96, 133, 149, 150, 164, 218, 221, 222, 224, 235, 237, 246, 274, 275, 321, 325, 326, 327, 332, 333, 334, 350, 364, 365, 398, 399],
    "Ambiguously_Correct": [3, 13, 36, 46, 75, 76, 77, 78, 82, 86, 88, 113, 119, 121, 131, 132, 133, 148, 189, 220, 221, 262, 263, 287, 295, 300, 303, 305, 307, 310, 319, 322, 332, 340, 343, 344, 348, 353, 355, 356, 363, 374, 377, 381, 386, 394],
    "Visually_Difficult": [4, 22, 23, 25, 27, 28, 31, 36, 58, 65, 69, 70, 77, 97, 116, 118, 134, 138, 159, 163, 172, 176, 182, 187, 200, 214, 226, 227, 232, 241, 255, 268, 286, 335, 352, 356, 373, 376],
    "Unusual_Image" : [31, 36, 38, 41, 42, 61, 62, 70, 78, 84, 93, 110, 114, 116, 128, 133, 136, 155, 159, 164, 173, 174, 188, 201, 203, 204, 206, 209, 218, 223, 239, 245, 246, 247, 254, 274, 275, 277, 280, 282, 293, 303, 307, 314, 319, 320, 327, 329, 339, 362, 367, 383, 384, 388, 393, 395],
    "Unusual_Text": [10, 41, 49, 58, 63, 68, 70, 152, 156, 159, 163, 174, 198, 201, 209, 214, 215, 221, 229, 233, 237, 253, 257, 264, 275, 287, 303, 315, 318, 323, 324, 326, 327, 335, 338, 342, 343, 345, 346, 351, 354, 359, 364, 376, 383, 385, 386, 387, 390, 394],
    "Complex_Reasoning": [16, 40, 44, 46, 55, 58, 81, 83, 93, 97, 103, 111, 116, 118, 128, 130, 135, 143, 144, 176, 190, 191, 192, 193, 199, 206, 208, 209, 210, 211, 217, 218, 219, 227, 228, 230, 234, 238, 241, 242, 249, 254, 258, 260, 262, 264, 267, 268, 275, 276, 281, 284, 286, 287, 292, 295, 296, 298, 299, 304, 311, 312, 316, 330, 331, 334, 336, 342, 347, 358, 361, 371, 373, 375, 382, 383, 392, 396],
    "NoTag": [0, 1, 2, 5, 6, 7, 8, 9, 11, 12, 14, 15, 17, 18, 19, 20, 21, 24, 26, 29, 30, 32, 33, 34, 35, 37, 39, 43, 45, 47, 48, 50, 51, 52, 53, 54, 56, 57, 59, 60, 64, 66, 67, 71, 79, 80, 85, 87, 89, 90, 91, 92, 94, 98, 99, 100, 101, 102, 104, 105, 106, 107, 108, 109, 112, 115, 117, 120, 122, 123, 124, 125, 126, 127, 129, 137, 139, 140, 141, 142, 145, 146, 147, 151, 153, 154, 157, 158, 160, 161, 162, 165, 166, 167, 168, 169, 170, 171, 175, 177, 178, 179, 180, 181, 183, 184, 185, 186, 194, 195, 196, 197, 202, 205, 207, 212, 213, 216, 225, 231, 236, 240, 243, 244, 248, 250, 251, 252, 256, 259, 261, 265, 266, 269, 270, 271, 272, 273, 278, 279, 283, 285, 288, 289, 290, 291, 294, 297, 301, 302, 306, 308, 309, 317, 328, 337, 341, 349, 357, 360, 366, 368, 369, 370, 372, 378, 379, 380, 389, 391, 397, 313]
}

STATS_LIST = [] 

id_to_category = {}
for category in categories:
    for num in categories[category]:
        id_to_category[num] = category


for i in range(3):

    performances = {}
    totals = {}
    corrects = {}
    for category in categories:
        performances[category] = 0
        totals[category] = 0
        corrects[category] = 0

    with open(text_path.format(i+1), "r") as f:
        stats = {}

        for line in f:

            info, response = line.split("|||")
            example_num, label = info.split("_")
            example_num = int(example_num)
            label = int(label)
            if example_num not in stats:
                stats[example_num] = [False, False]
            if label == 0:
                if response[0] == "A":
                    stats[example_num][0] = True
                elif response[0] == "B":
                    stats[example_num][0] = False
                else:
                    stats[example_num][0] = True if random.random() > 0.5 else False
            if label == 1:
                if response[0] == "B":
                    stats[example_num][1] = True
                elif response[0] == "A":
                    stats[example_num][1] = False
                else:
                    stats[example_num][1] = True if random.random() > 0.5 else False
  
    
    STATS_LIST.append(stats)

threshold = 2
correct = 0
total = 0
stats = STATS_LIST[0]
for example in stats:
    
    correct_list = []
    for stat in STATS_LIST:
        category = id_to_category[example_num]
        predictions = stat[example]
        category = id_to_category[example]
        totals[category] += 1
        if predictions[0] and predictions[1]:
            correct_list.append(True)
        else:
            correct_list.append(False)
    total += 1
    if sum(correct_list) > threshold:
        correct += 1

print("Result", correct/total)
# Out:
# hi
# Found cached dataset winoground (/ua/ossowski/.cache/huggingface/datasets/facebook___winoground/default/0.0.0/72585f4d9cd5a28790bb9bc2adbdd45633f36dfbf85df529e0756e114e134285)
# 100%|██████████| 1/1 [00:00<00:00, 745.79it/s]
# Result 0.2825
